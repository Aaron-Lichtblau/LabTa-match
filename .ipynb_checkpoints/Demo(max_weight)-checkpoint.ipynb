# %%
from pulp import *
import max_weight_cap
import labTA
from schedule import Schedule
import stats
import swap
import input_creator
import output_creator
import gspread
import copy
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np

PREV_SLOT = {'M_9': 'M_7', 'Tu_9': 'Tu_7', 'W_9': 'W_7', 'Th_9': 'Th_7', 'F_9': 'F_7', 'Sa_5': 'Sa_3', 'Su_7': 'Su_5', 'Su_8': 'Su_6', 'Su_9': 'Su_7'} #dict of slots and their prev slots

# %%
def highlight_negative(col):
    is_negative = col < 0.0
    return ['background-color: yellow' if v else '' for v in is_negative]

# %% [markdown]
# **Hand-picked Schedule Section**

# %%
# make dataframe
df_hand = input_creator.get_df()

#get experience dict
exp_dict = {}
students = list(df_hand['name'])
for index in range(len(df_hand['name'])):
    exp_dict[str(df_hand.at[index, 'name'])] = int(df_hand.at[index, 'experience'])

# %%
hand_data = {"M_7" : ['Tajreen Ahmed', 'Urvashi Uberoy', 'Ze Xin Koh', 'Kyle Johnson', 'Ariel Rakovitsky', 'Caroline di Vittorio', 'Khyati Agrawal', 'Annie Zhou'], "M_9" : ['Cathleen Kong', 'HJ Suh', 'Ze Xin Koh', 'Akash Pattnaik', 'Ariel Rakovitsky', 'Caroline di Vittorio'],"Tu_7" : ['Uri Schwartz','Alan Ding','Urvashi Uberoy','Akash Pattnaik','Bobby Morck'], "Tu_9" : ['Justin Chang','Alan Ding','Caio Costa','Bobby Morck'],"W_7" : ['Michelle Woo','Avi Bendory','Kawin Tiyawattanaroj','Tajreen Ahmed'], "W_9" : ['Michelle Woo','Avi Bendory','Kawin Tiyawattanaroj','Khyati Agrawal'],"Th_7" : ['Charlie Smith','Niranjan Shankar','Caio Costa','Ryan Golant'], "Th_9" : ['Charlie Smith','Arjun Devraj','Somya Arora','Jason Xu'],"F_7" : ['Annie Zhou','Nathan Alam','Sahan Paliskara','Connie Miao'], "F_9" : ['Somya Arora','Nathan Alam','Sahan Paliskara','Ryan Golant'],"Sa_3" : ['Anu Vellore','Ibrahim Ali Hashmi','Aditya Kohli','Lily Zhang','Ezra Zinberg'], "Sa_4" : ['Jackson Deitelzweig','Donovan Coronado','Jason Xu','Uri Schwartz','Ally Dalman','Catherine Yu'],"Sa_5" : ['Anu Vellore','Ibrahim Ali Hashmi','Connie Miao','Lily Zhang','Ezra Zinberg'],"Su_5" : ['Nala Sharadjaya','Arjun Devraj','Donovan Coronado','Niranjan Shankar'],"Su_6" : ['Kyle Johnson','Sandun Bambarandage','Jackson Deitelzweig'],"Su_7" : ['Yashodhar Govil','Shirley Z.','Aniela Macek','Chuk Uzoegwu','Nala Sharadjaya','Aditya Kohli'],"Su_8" : ['Cathleen Kong','Sandun Bambarandage','HJ Suh','Ally Dalman'], "Su_9" : ['Yashodhar Govil','Shirley Z.','Aniela Macek','Chuk Uzoegwu','Justin Chang','Catherine Yu']}
hand_sched = Schedule(hand_data)

#print df, exp and happiness stats
max_weight_cap.schedule_to_df(df_hand, hand_sched)
styled_df = df_hand.style.apply(highlight_negative, subset=list(hand_sched.schedule.keys()))
display(styled_df)

print("Hand-Picked schedule stats:")
stats.exp_stats(exp_dict, hand_sched)
hand_hap = stats.sched_happiness(df_hand, hand_sched, PREV_SLOT)
print('Average Happiness: ', hand_hap[0])
print()
print('Availability to happiness correlation: ', hand_hap[1])
print()
print('Variance of happiness: ', hand_hap[2])
print()
print('Min happy outlier students: ', hand_hap[3])
print()
print('Max happy outlier students: ', hand_hap[4])
print()
print('Students who got 1\'s: ', hand_hap[5])
print()
print('Students without shifts: ', hand_hap[6])
print()
print('Students who got wrong slot type: ', hand_hap[7])
print()
# Out:
# <style  type="text/css" >
#     #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow1_col1 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow1_col3 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow2_col1 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow2_col5 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow3_col16 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow3_col18 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow4_col1 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow4_col15 {
#             background-color:  yellow;
#         }    #T_98e409e8_c6d3_11ea_8aa7_8c85901bdb4erow5_col8 {
#             background-color:  yellow;
# ...

# %% [markdown]
# **Linear Program (max-weight) Schedule Section**

# %%
df = input_creator.make_df()

#example weights
weight_dict = {}
weight_dict['slot_type'] = 4
weight_dict['no_1'] = 9
weight_dict['guarantee_shift'] = 8
weight_dict['avail'] = 7
weight_dict['shift_cap'] = 3
weight_dict['equality'] = 6

#create graph nodes and weight edges
graph_data = max_weight_cap.create_graph(df, weight_dict)
student_nodes = graph_data[0]
slot_nodes = graph_data[1]
wt = graph_data[2]

#solve the problem and get the ordered schedule
p = max_weight_cap.solve_wbm(student_nodes, slot_nodes, wt)
unordered_sched_dict = max_weight_cap.get_solution(p)
max_weight_sched = max_weight_cap.order_sched(df, unordered_sched_dict)

#print df, exp and happiness stats
max_weight_cap.schedule_to_df(df, max_weight_sched)
styled_df = df.style.apply(highlight_negative, subset=list(max_weight_sched.schedule.keys()))
display(styled_df)

#Evaluate happiness stats of schedule
post_hap = stats.sched_happiness(df, max_weight_sched, PREV_SLOT)

print('Average Happiness: ', post_hap[0])
print()
print('Availability to happiness correlation: ', post_hap[1])
print()
print('Variance of happiness: ', post_hap[2])
print()
print('Min happy outlier students: ', post_hap[3])
print()
print('Max happy outlier students: ', post_hap[4])
print()
print('Students who got 1\'s: ', post_hap[5])
print()
print('Students without shifts: ', post_hap[6])
print()
print('Students who got wrong slot type: ', post_hap[7])
print()
# Out:
# Status: Optimal
# <style  type="text/css" >
#     #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow0_col3 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow1_col4 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow2_col11 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow3_col1 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow4_col1 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow5_col15 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow6_col1 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow6_col3 {
#             background-color:  yellow;
#         }    #T_325414ec_c6d4_11ea_8aa7_8c85901bdb4erow6_col11 {
# ...
