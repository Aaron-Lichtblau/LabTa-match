# %% [markdown]
# ## **Welcome to the LabTA Scheduler**

# %%
from schedule import Schedule
import input_creator
import output_creator
import stats
import graph
import solver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-cc964f05ae27> in <module>
#       3 import output_creator
#       4 import stats
# ----> 5 import graph
#       6 import solver
#
# ~/Desktop/Matching_Projects/LabTA match/graph.py in <module>
# ----> 1 import node_helpers
#       2
#       3 #-------------------------------------------------------------------------------
#       4 # Weight Edge Functions
#       5 #-------------------------------------------------------------------------------
#
# ModuleNotFoundError: No module named 'node_helpers'

# %%
def color_schedule(val):
    if int(val) == -3.0:
        background_color = 'green'
    elif int(val) == -2.0:
        background_color = 'yellow'
    elif int(val) == -1.0:
        background_color = 'red'
    else:
        background_color = ''
    return 'background-color: %s' % background_color

# %%
def color_wrong_type(s):
    '''
    highlight the wrong types dark orange
    '''
    is_wrong = s == True
    return ['background-color: darkorange' if v else '' for v in is_wrong]

# %% [markdown]
# ## **Default Schedule Inputs**
#
# These inputs are the defaults based on the Fall 2019 LabTA Schedule. Please edit the title of the csv file to being your own csv file. Change the slotdict keys and values as needed for changes in the slots and number of shifts per slot in the schedule.

# %%
#Default csv file
csv_file = 'default_input.csv'

#dict of target number of students in each slot
slotdict = {"Mo_1900" : 7, "Mo_2100" : 6,"Tu_1900" : 5, "Tu_2100" : 5,"We_1900" : 4, "We_2100" : 3,"Th_1900" : 3, "Th_2100" : 3,"Fr_1900" : 4, "Fr_2100" : 3,"Sa_1500" : 4, "Sa_1600" : 4,"Sa_1700" : 4,"Su_1700" : 5,"Su_1800" : 3,"Su_1900" : 5,"Su_2000" : 4, "Su_2100" : 6}

# %%
duration = 120 #length of slots (in minutes)

#default column values
gap = 180
cap = 2
exp = 3
skill = 4

#list of slots that need more skilled TA's
stress_slots = []

#numeric value indicating how many TAs the scheduler can hire above the targeted value for any given slot
target_delta = 0

#number of shifts the scheduler can assign in addition to the slotdict shift numbers
flex_shifts = 0

#sets minimum number of experienced TA's per slot
MIN_EXP = 0

#sets minimum number of skilled TA's per stress slot
MIN_SKILL = 0

#gets number of slots
NUM_SLOTS = 0
for slot in slotdict:
    NUM_SLOTS += slotdict[slot]
    
#Default weights
weight_dict = {}
weight_dict['slot_type'] = 4
weight_dict['no_1'] = 3
weight_dict['guarantee_shift'] = 5
weight_dict['avail'] = 7
weight_dict['shift_cap'] = 5
weight_dict['equality'] = 3

# %%
def results(weight_dict, input_csv, slotdict):
    
    df = input_creator.get_df(csv_file)
    students = list(df['name'])
    input_creator.check_col(df, gap, cap, exp, skill)

    #dict of slots to check as keys, and overlapping slots as values (student won't be placed in overlap)
    slots = input_creator.get_slots(df)

    #dict of slots and their prev slots
    PREV_SLOT = input_creator.get_prev_slots(df, duration)

    #create graph nodes and weight edges
    graph_data = graph.create_graph(df, weight_dict, slotdict, PREV_SLOT, NUM_SLOTS, duration)
    student_nodes = graph_data[0]
    slot_nodes = graph_data[1]
    wt = graph_data[2]

    #solve the problem, get the ordered schedule, updated df
    results = solver.run_solver(student_nodes, slot_nodes, wt, df, slotdict, MIN_EXP, MIN_SKILL, stress_slots, target_delta, flex_shifts, duration)
    schedule = results[0]
    df = results[1]

    #get stats
    happiness_stats = stats.hap_stats(df, schedule)
    corr_stats = stats.corr_stats(df, schedule)
    student_stats = stats.stud_stats(df, schedule, PREV_SLOT)

    df['wrong type'] = student_stats[3]
    cols = ['name']
    cols2 = list(slotdict.keys())
    cols.extend(cols2)
    cols3 = ['happiness', 'wrong type', 'slot_type', 'availability', 'cap', 'experience', 'skill', 'hours']
    cols.extend(cols3)
    df = df[cols]
    styled_df = df.style.\
        applymap(color_schedule, subset = pd.IndexSlice[:, max_weight_sched.schedule.keys()]).\
        apply(color_wrong_type, subset=['wrong type'])
    
    display(styled_df)
    
    print("Max Weight schedule stats:")
#     stats.exp_stats(exp_dict, schedule)
#     stats.skill_stats(skill_dict, schedule)
    
    #Evaluate happiness stats of schedule
    print('Average Happiness: ', happiness_stats[0])
    print()
    print('Standard deviation of happiness: ', happiness_stats[1])
    print()
    print('Min happy outlier students: ', happiness_stats[2])
    print()
    print('Availability to happiness correlation: ', corr_stats[0])
    print()
    print('Skill to happiness correlation: ', corr_stats[1])
    print()
    print('Experience to happiness correlation: ', corr_stats[2])
    print()
    print('Students who got 1\'s: ', student_stats[0])
    print()
    print('Students without shifts: ', student_stats[1])
    print()
    print('Students who got wrong slot type: ', student_stats[2])
    print()
    
    return(schedule)

# %%
max_weight_sched = results(weight_dict, csv_file, slotdict)
# Out:
# /Users/aaronlichtblau/opt/miniconda3/lib/python3.7/site-packages/pulp/pulp.py:1114: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Status: Optimal
# <style  type="text/css" >
#     #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col1 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col2 {
#             background-color:  green;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col3 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col4 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col5 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col6 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col7 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col8 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col9 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col10 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col11 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col12 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col13 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col14 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow0_col15 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow4_col5 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow4_col6 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow4_col7 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow4_col8 {
#             background-color:  ;
#         }    #T_03593870_dd1d_11ea_9a87_8c85901bdb4erow4_co
# Max Weight schedule stats:
# Average Happiness:  80.37037037037037
#
# Availability to happiness correlation:  0.6167956505616865
#
# Standard deviation of happiness:  36.113053560810535
#
# Min happy outlier students:  []
#
# Max happy outlier students:  []
#
# Students who got 1's:  []
#
# Students without shifts:  ['Urvashi Uberoy', 'Tajreen Ahmed', 'Kyle Johnson', 'Donovan Coronado', 'Chuk Uzoegwu', 'Alan Ding', 'Connie Miao']
#
# Students who got wrong slot type:  ['Ben Schiffer', 'Somya Arora', 'Annie Zhou', 'HJ Suh', 'Jason Xu', 'Nathan Alam', 'Anu Vellore', 'Avi Bendory', 'Lily Zhang', 'Nala Sharadjaya', 'Catherine Yu']

# %% [markdown]
# ## **Print Schedule:**

# %%
max_weight_sched.print_sched()
# Out:
# Mo_19 :
# ['Aditya Kohli', 'Akash Pattnaik', 'Annie Zhou', 'Caroline di Vittorio', 'Khyati Agrawal', 'Kyle Johnson', 'Nala Sharadjaya', 'Urvashi Uberoy']
# Mo_21 :
# ['Ben Schiffer', 'HJ Suh', 'Michelle Woo', 'Sandun Bambarandage', 'Yashodhar Govil', 'Ze Xin Koh']
# Tu_19 :
# ['Ally Dalman', 'Bobby Morck', 'Justin Chang', 'Sahan Paliskara', 'Uri Schwartz']
# Tu_21 :
# ['Alan Ding', 'Bobby Morck', 'Justin Chang', 'Sahan Paliskara', 'Shaurya Garg']
# We_19 :
# ['Arjun Devraj', 'Charlie Smith', 'Kyle Johnson', 'Tajreen Ahmed', 'Urvashi Uberoy']
# We_21 :
# ['Ariel Rakovitsky', 'Caroline di Vittorio', 'Charlie Smith', 'Jason Xu', 'Kawin Tiyawattanaroj']
# Th_19 :
# ['Arjun Devraj', 'Kawin Tiyawattanaroj', 'Khyati Agrawal', 'Niranjan Shankar', 'Tajreen Ahmed']
# Th_21 :
# ['Avi Bendory', 'Caio Costa', 'Catherine Yu', 'Niranjan Shankar']
# Fr_19 :
# ['Annie Zhou', 'Connie Miao', 'Donovan Coronado', 'Somya Arora']
# Fr_21 :
# ['Lily Zhang', 'Nathan Alam', 'Ryan Golant', 'Somya Arora']
# Sa_15 :
# ['Anu Vellore', 'Caio Costa', 'Ezra Zinberg', 'Ibrahim Ali Hashmi', 'Michelle Woo']
# Sa_16 :
# ['Alan Ding', 'Donovan Coronado', 'Jackson Deitelzweig', 'Jason Xu', 'Lily Zhang', 'Ze Xin Koh']
# Sa_17 :
# ['Anu Vellore', 'Connie Miao', 'Ezra Zinberg', 'Ibrahim Ali Hashmi', 'Shaurya Garg']
# Su_17 :
# ['Avi Bendory', 'Catherine Yu', 'Jackson Deitelzweig', 'Nathan Alam']
# Su_18 :
# ['Ben Schiffer', 'Nala Sharadjaya', 'Sandun Bambarandage']
# Su_19 :
# ['Aditya Kohli', 'Akash Pattnaik', 'Aniela Macek', 'Cathleen Kong', 'Chuk Uzoegwu', 'Shirley']
# Su_20 :
# ['Ally Dalman', 'Ariel Rakovitsky', 'Uri Schwartz', 'Yashodhar Govil']
# Su_21 :
# ['Aniela Macek', 'Cathleen Kong', 'Chuk Uzoegwu', 'HJ Suh', 'Ryan Golant', 'Shirley']

# %% [markdown]
# ## **Advanced Schedule Inputs**
#
# These inputs are for customizing the schedule based on more detailed preferences

# %%
#custom weights
weight_dict_custom = {}
weight_dict_custom['slot_type'] = 5
weight_dict_custom['no_1'] = 7
weight_dict_custom['guarantee_shift'] = 6
weight_dict_custom['avail'] = 6
weight_dict_custom['shift_cap'] = 3
weight_dict_custom['equality'] = 3

# %%
#list of slots that need more skilled TA's
stress_slots = ["Mo_19", "Mo_21", "Su_20", "Su_21"]

#sets minimum number of skilled TA's per stress slot
MIN_SKILL = 2

#numeric value indicating how many TAs the scheduler can hire above the targeted value for any given slot
target_delta = 2

#number of shifts the scheduler can assign in addition to the slotdict shift numbers
flex_shifts = 4

#sets minimum number of experienced TA's per slot
MIN_EXP = 3

# %%
custom_schedule = results(weight_dict_custom, csv_file, slotdict)
# Out:
# Status: Optimal
# <style  type="text/css" >
#     #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col1 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col2 {
#             background-color:  green;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col3 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col4 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col5 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col6 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col7 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col8 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col9 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col10 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col11 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col12 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col13 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col14 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col15 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col16 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col17 {
#             background-color:  green;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow0_col18 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow4_col7 {
#             background-color:  ;
#         }    #T_15730aae_d38b_11ea_9ad3_8c85901bdb4erow4_col8 {
#             background-color:  ;
#         }    #T_15730aae_d38b
# Max Weight schedule stats:
# Average Happiness:  97.40740740740742
#
# Availability to happiness correlation:  0.14183773505991065
#
# Variance of happiness:  0.0037317620650954026
#
# Min happy outlier students:  []
#
# Max happy outlier students:  []
#
# Students who got 1's:  []
#
# Students without shifts:  []
#
# Students who got wrong slot type:  ['Ben Schiffer', 'Somya Arora', 'Nathan Alam', 'Avi Bendory', 'Lily Zhang', 'Michelle Woo', 'Nala Sharadjaya', 'Catherine Yu']

# %%
custom_schedule.print_sched()
# Out:
# Mo_19 :
# ['Aditya Kohli', 'Akash Pattnaik', 'Annie Zhou', 'Ariel Rakovitsky', 'HJ Suh', 'Khyati Agrawal', 'Kyle Johnson', 'Yashodhar Govil']
# Mo_21 :
# ['Ariel Rakovitsky', 'Ben Schiffer', 'Cathleen Kong', 'HJ Suh', 'Sandun Bambarandage', 'Ze Xin Koh']
# Tu_19 :
# ['Bobby Morck', 'Caroline di Vittorio', 'Sahan Paliskara', 'Uri Schwartz', 'Urvashi Uberoy']
# Tu_21 :
# ['Alan Ding', 'Bobby Morck', 'Justin Chang', 'Sahan Paliskara', 'Shaurya Garg']
# We_19 :
# ['Arjun Devraj', 'Avi Bendory', 'Kawin Tiyawattanaroj', 'Michelle Woo', 'Tajreen Ahmed']
# We_21 :
# ['Arjun Devraj', 'Caroline di Vittorio', 'Charlie Smith', 'Jason Xu', 'Kawin Tiyawattanaroj']
# Th_19 :
# ['Caio Costa', 'Catherine Yu', 'Khyati Agrawal', 'Tajreen Ahmed', 'Urvashi Uberoy']
# Th_21 :
# ['Charlie Smith', 'Jason Xu', 'Nala Sharadjaya', 'Niranjan Shankar']
# Fr_19 :
# ['Annie Zhou', 'Connie Miao', 'Donovan Coronado', 'Somya Arora']
# Fr_21 :
# ['Lily Zhang', 'Nathan Alam', 'Ryan Golant', 'Somya Arora']
# Sa_15 :
# ['Anu Vellore', 'Caio Costa', 'Ezra Zinberg', 'Ibrahim Ali Hashmi', 'Michelle Woo']
# Sa_16 :
# ['Alan Ding', 'Ally Dalman', 'Donovan Coronado', 'Jackson Deitelzweig', 'Lily Zhang', 'Ze Xin Koh']
# Sa_17 :
# ['Anu Vellore', 'Connie Miao', 'Ezra Zinberg', 'Ibrahim Ali Hashmi', 'Shaurya Garg']
# Su_17 :
# ['Avi Bendory', 'Catherine Yu', 'Jackson Deitelzweig', 'Niranjan Shankar']
# Su_18 :
# ['Kyle Johnson', 'Nala Sharadjaya', 'Sandun Bambarandage']
# Su_19 :
# ['Aditya Kohli', 'Akash Pattnaik', 'Aniela Macek', 'Chuk Uzoegwu', 'Shirley', 'Uri Schwartz']
# Su_20 :
# ['Ally Dalman', 'Nathan Alam', 'Ryan Golant', 'Yashodhar Govil']
# Su_21 :
# ['Aniela Macek', 'Ben Schiffer', 'Cathleen Kong', 'Chuk Uzoegwu', 'Justin Chang', 'Shirley']
